# %% [markdown]
# # **Data Exploration**
#
# In dieser Lektion geht es darum, das Handwerk der Data Exploration besser zu beherrschen.
#
# Nicht alle Fragen, die an die Tabelle gestellt werden, sind unbedingt interessant - es geht eher darum, ein Gefühl dafür zu entwickeln, wie man mithilfe von Spaltenmanipulationen und Aggregationen solche Fragen beantwortet. Experimentiere gerne herum und google nach Befehlen, wenn du nicht weiter weißt. Es gibt eine Reihe von Methoden für DataFrames, die nicht in unserem Tutorial abgedeckt wurden - nachschlagen gehört dazu. Mach dir keinen Stress mit den Aufgaben - das Verständnis ist am Ende wichtiger, als dass alle Aufgaben fertig sind.
#
# Du hast einen bereinigten Datensatz vor dir.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
path_orders = "../data_sets/merch_sales_orders.csv"
path_products = "../data_sets/merch_sales_products.csv"

# %%
df_orders = pd.read_csv(path_orders)
df_products = pd.read_csv(path_products)

# %%
display(df_orders)
# Out:
#       Order ID  Order Date Product ID Product Category Buyer Gender  \
# 0       189440  2024-07-21     BF1543         Clothing         Male
# 1       187385  2024-07-20     BF1543         Clothing         Male
# 2       181844  2024-07-21     BF1544            Other       Female
# 3       197934  2024-08-19     BF1544            Other         Male
# 4       122470  2024-01-06     BF1545            Other       Female
# ...        ...         ...        ...              ...          ...
# 7389    136943  2023-12-10     BF1548         Clothing         Male
# 7390    172276  2024-01-24     BF1546         Clothing       Female
# 7391    160191  2023-12-19     BF1552        Ornaments         Male
# 7392    195268  2023-12-07     BF1555            Other         Male
# 7393    138160  2024-10-23     BF1544            Other       Female
#
#       Buyer Age Order Location International Shipping  Sales Price  \
# 0            30     New Jersey                     No          100
# ...

# %%
display(df_products)
# Out:
#    Product ID Product Name Manufacturer Country        Brand   Material
# 0      BF1543   Sweatshirt           Bangladesh         Mike     Cotton
# 1      BF1544        Boots                China      Aldidas    Leather
# 2      BF1545      Sneaker                Italy  Limbertands    Leather
# 3      BF1546        Jeans           Bangladesh      Aldidas      Denim
# 4      BF1547         Ring                Italy       Vossil     Silver
# 5      BF1548      T-Shirt                China         Mike     Cotton
# 6      BF1549       Shorts               Brazil   Over Armor  Polyester
# 7      BF1550       Jacket                Italy         Mike  Polyester
# 8      BF1551     Bracelet               Sweden       Carter      Steel
# 9      BF1552        Chain               Sweden       Vossil      Brass
# 10     BF1553    Ear Rings                Italy       Carter     Silver
# 11     BF1554    Nose Ring              Germany       Carter      Steel
# ...

# %% [markdown]
# ## **Aufgabe 1:** Wieviele verschiedene Produkte gibt es?

# %% [markdown]
# ## **Aufgabe 2:** Gib einen Überblick über die einzelnen Produkte und deren Kategorien.

# %% [markdown]
# ## **Aufgabe 3:** Welcher Zeitraum wird durch den Datensatz abgedeckt?

# %% [markdown]
# ## **Aufgabe 4:** Wieviele Bestellungen erfolgten durch International Shipping?

# %% [markdown]
# ## **Aufgabe 5:** Gib eine Übersicht, wieviele Produkte jede Kategorie hat.

# %% [markdown]
# ## **Aufgabe 6:** Welche Bestellung hat den meisten Umsatz gebracht?

# %% [markdown]
# ## **Aufgabe 7:** Zeig den Umsatz pro Stadt für August 2024.

# %% [markdown]
# ## **Aufgabe 8:** Wie hoch sind die Shipping Sales im Durchschnitt?

# %% [markdown]
# ## **Aufgabe 9:** Mit welcher Marke wurde der meisten Umsatz gemacht? Vergleiche die Umsätze der Marken in einem Diagramm.

# %% [markdown]
# ## **Aufgabe 10:** Stelle den Verlauf der Anzahl der Bestellungen vom 1.8.24 bis 30.9.24 graphisch dar.

# %% [markdown]
# ## **Aufgabe 11:** Berechne den durchschnittlichen Umsatz für jeden Wochentag und vergleiche in einem Diagramm.

# %% [markdown]
# ## **Aufgabe 12:** An insgesamt wievielen Tagen wurden keine Sweatshirts bestellt?
